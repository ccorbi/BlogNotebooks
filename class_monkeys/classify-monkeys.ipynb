# %%
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import torch
import torchvision
import torchvision.transforms as transforms


import matplotlib.pylab as plt
import seaborn as sns
from PIL import Image
# %matplotlib inline

# %% [markdown]
# DataSet from Kaggle dataset, 10 monkey species.
# https://www.kaggle.com/slothkong/10-monkey-species

# %%
img = Image.open('./training/n9/n9163.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=445x336 at 0x7F8D7B33AA90>

# %%
img = Image.open('./training/n2/n2017.jpg')
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=864x1302 at 0x7F8D7B2E0BA8>

# %%
#  CNN example

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.conv1 = nn.Conv2d(3, 6, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(6, 16, 5)
        self.fc1 = nn.Linear(16 * 53 * 53, 225)
        self.fc2 = nn.Linear(225, 84)
        self.fc3 = nn.Linear(84, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = x.view(-1, 16 * 53 * 53)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x


net = Net()

# init
net = Net()

# %%
# init
# loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, momentum=0.9)

# %%
# data normalization , resizer  and crop
# borders have very little or no information
# heterogenic sizes on the dataset
normalize = transforms.Normalize(
   mean=[0.485, 0.456, 0.406],
   std=[0.229, 0.224, 0.225]
)
preprocess = transforms.Compose([
   transforms.Resize(256),
    transforms.CenterCrop(224),
   transforms.ToTensor(),
   normalize
])

# %%
# load training data
trainset = torchvision.datasets.ImageFolder(root='training/', transform=preprocess)

# %%
# load Validation data
valset = torchvision.datasets.ImageFolder(root='validation/', transform=preprocess)

# %%
trainset.classes
# Out:
# ['n0', 'n1', 'n2', 'n3', 'n4', 'n5', 'n6', 'n7', 'n8', 'n9']

# %%
# create a loader
trainloader = torch.utils.data.DataLoader(trainset, batch_size=12,
                                           shuffle=True, num_workers=2)

# %%
valloader = torch.utils.data.DataLoader(valset, batch_size=1,
                                           shuffle=True, num_workers=2)

# %%
# quick & dirty eval func
def eval(model):
    correct = 0
    total = 0
    for data in valloader:
        images, labels = data
        outputs = model(Variable(images))
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum()
    acc = 100 * correct / total
    print('Accuracy of the network on the {} test images: {:.3f}'.format(total, acc ))
    return acc

# %%
def training(model, epochs=20, optimizer= optimizer):
    historic_loss = list()
    historic_acc = list()
    for epoch in range(epochs):  # loop over the dataset multiple times

        running_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # get the inputs
            inputs, labels = data

            # wrap them in Variable
            inputs, labels = Variable(inputs), Variable(labels)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = model(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.data[0]
            if i % 20 == 19:    # print every 2000 mini-batches
                print('[%d, %5d] loss: %.6f' %
                      (epoch + 1, i + 1, running_loss / 20))
                running_loss = 0.0

        historic_loss.append(loss.data[0])
        historic_acc.append(eval(model))
    print('Finished Training')
    return historic_loss, historic_acc

# %%
netl, neta = training(net, optimizer=optimizer)
# Out:
# [1,    20] loss: 2.308226
# [1,    40] loss: 2.297672
# [1,    60] loss: 2.282898
# [1,    80] loss: 2.249513
# Accuracy of the network on the 272 test images: 19.853
# [2,    20] loss: 2.089754
# [2,    40] loss: 2.024970
# [2,    60] loss: 2.002588
# [2,    80] loss: 1.953252
# Accuracy of the network on the 272 test images: 23.162
# [3,    20] loss: 1.829099
# [3,    40] loss: 1.713527
# [3,    60] loss: 1.847542
# [3,    80] loss: 1.734335
# Accuracy of the network on the 272 test images: 35.294
# [4,    20] loss: 1.526339
# [4,    40] loss: 1.608363
# [4,    60] loss: 1.467028
# [4,    80] loss: 1.353220
# Accuracy of the network on the 272 test images: 44.853
# [5,    20] loss: 1.314855
# [5,    40] loss: 1.251866
# [5,    60] loss: 1.246212
# [5,    80] loss: 1.194470
# Accuracy of the network on the 272 test images: 47.059
# [6,    20] loss: 0.997495
# [6,    40] loss: 0.887460
# [6,    60] loss: 1.063961
# [6,    80] loss: 0.959226
# Accuracy of the network on the 272 test images: 51.103
# [7,    20] loss: 0.786871
# [7,    40] loss: 0.657775
# [7,    60] loss: 0.783074
# [7,    80] loss: 0.895485
# Accuracy of the network on the 272 test images: 57.721
# [8,    20] loss: 0.410808
# [8,    40] loss: 0.598377
# [8,    60] loss: 0.632287
# [8,    80] loss: 0.614321
# Accuracy of the network on the 272 test images: 51.103
# [9,    20] loss: 0.410938
# [9,    40] loss: 0.487031
# [9,    60] loss: 0.629326
# [9,    80] loss: 0.417140
# Accuracy of the network on the 272 test images: 59.191
# [10,    20] loss: 0.399596
# [10,    40] loss: 0.311125
# [10,    60] loss: 0.243004
# [10,    80] loss: 0.294710
# Accuracy of the network on the 272 test images: 60.294
# [11,    20] loss: 0.155768
# [11,    40] loss: 0.103980
# [11,    60] loss: 0.152091
# [11,    80] loss: 0.238282
# Accuracy of the network on the 272 test images: 57.721
# [12,    20] loss: 0.120707
# [12,    40] loss: 0.116362
# [12,    60] loss: 0.118413
# [12,    80] loss: 0.135481
# Accuracy of the network on the 272 test images: 54.044
# [13,    20] loss: 0.215471
# [13,    40] loss: 0.248111
# [13,    60] loss: 0.143300
# [13,    80] loss: 0.156248
# Accuracy of the network on the 272 test images: 58.824
# [14,    20] loss: 0.085115
# [14,    40] loss: 0.101713
# [14,    60] loss: 0.106905
# [14,    80] loss: 0.045609
# Accuracy of the network on the 272 test images: 58.088
# [15,    20] loss: 0.026122
# [15,    40] loss: 0.039062
# [15,    60] loss: 0.008373
# [15,    80] loss: 0.008720
# Accuracy of the network on the 272 test images: 59.191
# [16,    20] loss: 0.002463
# [16,    40] loss: 0.009344
# [16,    60] loss: 0.002474
# [16,    80] loss: 0.007963
# Accuracy of the network on the 272 test images: 58.456
# [17,    20] loss: 0.001927
# [17,    40] loss: 0.002494
# [17,    60] loss: 0.001899
# [17,    80] loss: 0.001495
# Accuracy of the network on the 272 test images: 58.088
# [18,    20] loss: 0.001925
# [18,    40] loss: 0.000892
# [18,    60] loss: 0.001247
# [18,    80] loss: 0.000940
# Accuracy of the network on the 272 test images: 58.456
# [19,    20] loss: 0.001232
# [19,    40] loss: 0.000758
# [19,    60] loss: 0.000897
# [19,    80] loss: 0.000840
# Accuracy of the network on the 272 test images: 58.456
# [20,    20] loss: 0.000808
# [20,    40] loss: 0.000582
# [20,    60] loss: 0.000969
# [20,    80] loss: 0.000582
# Accuracy of the network on the 272 test images: 58.456
# Finished Training

# %%
# bigger CCN

class Bignet(nn.Module):
    def __init__(self):
        super(Bignet, self).__init__()
        self.conv1 = nn.Conv2d(3, 12, 8)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(12, 21, 8)
        
        self.fc1 = nn.Linear(21 * 50 * 50, 425)
        self.fc2 = nn.Linear(425, 100)
        self.fc3 = nn.Linear(100, 10)

    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        #print(x.size())
        x = x.view(-1, 21 * 50 * 50)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# init
bnet = Bignet()
optimizer = optim.SGD(bnet.parameters(), lr=0.001, momentum=0.9)

# %%
bnetl, bneta = training(bnet, optimizer=optimizer)
# Out:
# [1,    20] loss: 2.295945
# [1,    40] loss: 2.262884
# [1,    60] loss: 2.236525
# [1,    80] loss: 2.071252
# Accuracy of the network on the 272 test images: 28.309
# [2,    20] loss: 1.801384
# [2,    40] loss: 1.797541
# [2,    60] loss: 1.933941
# [2,    80] loss: 1.808075
# Accuracy of the network on the 272 test images: 34.926
# [3,    20] loss: 1.548642
# [3,    40] loss: 1.595688
# [3,    60] loss: 1.776132
# [3,    80] loss: 1.570253
# Accuracy of the network on the 272 test images: 38.603
# [4,    20] loss: 1.397451
# [4,    40] loss: 1.411776
# [4,    60] loss: 1.468890
# [4,    80] loss: 1.285340
# Accuracy of the network on the 272 test images: 41.176
# [5,    20] loss: 1.045656
# [5,    40] loss: 1.086375
# [5,    60] loss: 1.180584
# [5,    80] loss: 1.332874
# Accuracy of the network on the 272 test images: 44.853
# [6,    20] loss: 0.928273
# [6,    40] loss: 0.867833
# [6,    60] loss: 1.006504
# [6,    80] loss: 0.993447
# Accuracy of the network on the 272 test images: 48.897
# [7,    20] loss: 0.645937
# [7,    40] loss: 0.657412
# [7,    60] loss: 0.653947
# [7,    80] loss: 0.652354
# Accuracy of the network on the 272 test images: 52.206
# [8,    20] loss: 0.419975
# [8,    40] loss: 0.439937
# [8,    60] loss: 0.417327
# [8,    80] loss: 0.431767
# Accuracy of the network on the 272 test images: 52.206
# [9,    20] loss: 0.178719
# [9,    40] loss: 0.183828
# [9,    60] loss: 0.264458
# [9,    80] loss: 0.347951
# Accuracy of the network on the 272 test images: 52.941
# [10,    20] loss: 0.232670
# [10,    40] loss: 0.187211
# [10,    60] loss: 0.175865
# [10,    80] loss: 0.117683
# Accuracy of the network on the 272 test images: 56.618
# [11,    20] loss: 0.064228
# [11,    40] loss: 0.073345
# [11,    60] loss: 0.069873
# [11,    80] loss: 0.186662
# Accuracy of the network on the 272 test images: 50.000
# [12,    20] loss: 0.252042
# [12,    40] loss: 0.212639
# [12,    60] loss: 0.115552
# [12,    80] loss: 0.095557
# Accuracy of the network on the 272 test images: 55.515
# [13,    20] loss: 0.104270
# [13,    40] loss: 0.147576
# [13,    60] loss: 0.058511
# [13,    80] loss: 0.044493
# Accuracy of the network on the 272 test images: 54.779
# [14,    20] loss: 0.086341
# [14,    40] loss: 0.036284
# [14,    60] loss: 0.044017
# [14,    80] loss: 0.069439
# Accuracy of the network on the 272 test images: 56.985
# [15,    20] loss: 0.396222
# [15,    40] loss: 0.231300
# [15,    60] loss: 0.127895
# [15,    80] loss: 0.154761
# Accuracy of the network on the 272 test images: 53.676
# [16,    20] loss: 0.157493
# [16,    40] loss: 0.081450
# [16,    60] loss: 0.033994
# [16,    80] loss: 0.098539
# Accuracy of the network on the 272 test images: 52.574
# [17,    20] loss: 0.080181
# [17,    40] loss: 0.051558
# [17,    60] loss: 0.019695
# [17,    80] loss: 0.093918
# Accuracy of the network on the 272 test images: 56.250
# [18,    20] loss: 0.030544
# [18,    40] loss: 0.006989
# [18,    60] loss: 0.005336
# [18,    80] loss: 0.004077
# Accuracy of the network on the 272 test images: 56.250
# [19,    20] loss: 0.001507
# [19,    40] loss: 0.001570
# [19,    60] loss: 0.000843
# [19,    80] loss: 0.000932
# Accuracy of the network on the 272 test images: 57.353
# [20,    20] loss: 0.000767
# [20,    40] loss: 0.000608
# [20,    60] loss: 0.000655
# [20,    80] loss: 0.000614
# Accuracy of the network on the 272 test images: 56.985
# Finished Training

# %%
# bigger CCN

class Complexnet(nn.Module):
    def __init__(self):
        super(Complexnet, self).__init__()
        self.conv1 = nn.Conv2d(3, 16, 5)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(16, 32, 5)
        self.conv3 = nn.Conv2d(32, 48, 5)

        self.fc1 = nn.Linear(48 * 24 * 24, 425)
        self.fc2 = nn.Linear(425, 128)
        self.fc3 = nn.Linear(128, 10)

        
        
    def forward(self, x):
        x = self.pool(F.relu(self.conv1(x)))
        x = self.pool(F.relu(self.conv2(x)))
        x = self.pool(F.relu(self.conv3(x)))

        #print(x.size())
        x = x.view(-1, 48 * 24 * 24)
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# init
cnet = Complexnet()
optimizer = optim.SGD(cnet.parameters(), lr=0.001, momentum=0.9)

# %%
cnetl, cneta = training(cnet, epochs=35, optimizer=optimizer)
# Out:
# [1,    20] loss: 2.298641
# [1,    40] loss: 2.296569
# [1,    60] loss: 2.285260
# [1,    80] loss: 2.264432
# Accuracy of the network on the 272 test images: 27.941
# [2,    20] loss: 2.171454
# [2,    40] loss: 2.066081
# [2,    60] loss: 2.042241
# [2,    80] loss: 2.004077
# Accuracy of the network on the 272 test images: 30.515
# [3,    20] loss: 1.827966
# [3,    40] loss: 2.002110
# [3,    60] loss: 1.815997
# [3,    80] loss: 1.820298
# Accuracy of the network on the 272 test images: 32.353
# [4,    20] loss: 1.791322
# [4,    40] loss: 1.677493
# [4,    60] loss: 1.738021
# [4,    80] loss: 1.808294
# Accuracy of the network on the 272 test images: 36.765
# [5,    20] loss: 1.593207
# [5,    40] loss: 1.772468
# [5,    60] loss: 1.568343
# [5,    80] loss: 1.576196
# Accuracy of the network on the 272 test images: 37.500
# [6,    20] loss: 1.403065
# [6,    40] loss: 1.514481
# [6,    60] loss: 1.411024
# [6,    80] loss: 1.369500
# Accuracy of the network on the 272 test images: 39.706
# [7,    20] loss: 1.134041
# [7,    40] loss: 1.247451
# [7,    60] loss: 1.280608
# [7,    80] loss: 1.358516
# Accuracy of the network on the 272 test images: 42.647
# [8,    20] loss: 1.112155
# [8,    40] loss: 1.012717
# [8,    60] loss: 1.179526
# [8,    80] loss: 1.098507
# Accuracy of the network on the 272 test images: 44.485
# [9,    20] loss: 0.751655
# [9,    40] loss: 0.762626
# [9,    60] loss: 0.884807
# [9,    80] loss: 0.799965
# Accuracy of the network on the 272 test images: 50.368
# [10,    20] loss: 0.474079
# [10,    40] loss: 0.545133
# [10,    60] loss: 0.599559
# [10,    80] loss: 0.631320
# Accuracy of the network on the 272 test images: 45.956
# [11,    20] loss: 0.446074
# [11,    40] loss: 0.280394
# [11,    60] loss: 0.349286
# [11,    80] loss: 0.345829
# Accuracy of the network on the 272 test images: 49.265
# [12,    20] loss: 0.319557
# [12,    40] loss: 0.204239
# [12,    60] loss: 0.231295
# [12,    80] loss: 0.327923
# Accuracy of the network on the 272 test images: 52.574
# [13,    20] loss: 0.120810
# [13,    40] loss: 0.179382
# [13,    60] loss: 0.124562
# [13,    80] loss: 0.102643
# Accuracy of the network on the 272 test images: 48.529
# [14,    20] loss: 0.107260
# [14,    40] loss: 0.157319
# [14,    60] loss: 0.103051
# [14,    80] loss: 0.081212
# Accuracy of the network on the 272 test images: 50.000
# [15,    20] loss: 0.064795
# [15,    40] loss: 0.078328
# [15,    60] loss: 0.048737
# [15,    80] loss: 0.031903
# Accuracy of the network on the 272 test images: 54.044
# [16,    20] loss: 0.007435
# [16,    40] loss: 0.006731
# [16,    60] loss: 0.044367
# [16,    80] loss: 0.071686
# Accuracy of the network on the 272 test images: 48.529
# [17,    20] loss: 0.016617
# [17,    40] loss: 0.008841
# [17,    60] loss: 0.015680
# [17,    80] loss: 0.007663
# Accuracy of the network on the 272 test images: 54.779
# [18,    20] loss: 0.001930
# [18,    40] loss: 0.002510
# [18,    60] loss: 0.001784
# [18,    80] loss: 0.001043
# Accuracy of the network on the 272 test images: 54.044
# [19,    20] loss: 0.001164
# [19,    40] loss: 0.000763
# [19,    60] loss: 0.000860
# [19,    80] loss: 0.001045
# Accuracy of the network on the 272 test images: 54.412
# [20,    20] loss: 0.000621
# [20,    40] loss: 0.000591
# [20,    60] loss: 0.000566
# [20,    80] loss: 0.000604
# Accuracy of the network on the 272 test images: 54.779
# [21,    20] loss: 0.000576
# [21,    40] loss: 0.000413
# [21,    60] loss: 0.000428
# [21,    80] loss: 0.000441
# Accuracy of the network on the 272 test images: 54.779
# [22,    20] loss: 0.000323
# [22,    40] loss: 0.000451
# [22,    60] loss: 0.000300
# [22,    80] loss: 0.000452
# Accuracy of the network on the 272 test images: 54.779
# [23,    20] loss: 0.000310
# [23,    40] loss: 0.000399
# [23,    60] loss: 0.000350
# [23,    80] loss: 0.000352
# Accuracy of the network on the 272 test images: 54.779
# [24,    20] loss: 0.000309
# [24,    40] loss: 0.000231
# [24,    60] loss: 0.000234
# [24,    80] loss: 0.000276
# Accuracy of the network on the 272 test images: 55.147
# [25,    20] loss: 0.000309
# [25,    40] loss: 0.000233
# [25,    60] loss: 0.000243
# [25,    80] loss: 0.000258
# Accuracy of the network on the 272 test images: 55.147
# [26,    20] loss: 0.000208
# [26,    40] loss: 0.000291
# [26,    60] loss: 0.000274
# [26,    80] loss: 0.000247
# Accuracy of the network on the 272 test images: 55.147
# [27,    20] loss: 0.000206
# [27,    40] loss: 0.000264
# [27,    60] loss: 0.000211
# [27,    80] loss: 0.000218
# Accuracy of the network on the 272 test images: 55.147
# [28,    20] loss: 0.000148
# [28,    40] loss: 0.000252
# [28,    60] loss: 0.000193
# [28,    80] loss: 0.000217
# Accuracy of the network on the 272 test images: 55.147
# [29,    20] loss: 0.000152
# [29,    40] loss: 0.000233
# [29,    60] loss: 0.000169
# [29,    80] loss: 0.000182
# Accuracy of the network on the 272 test images: 55.147
# [30,    20] loss: 0.000143
# [30,    40] loss: 0.000189
# [30,    60] loss: 0.000169
# [30,    80] loss: 0.000177
# Accuracy of the network on the 272 test images: 55.147
# [31,    20] loss: 0.000131
# [31,    40] loss: 0.000113
# [31,    60] loss: 0.000165
# [31,    80] loss: 0.000201
# Accuracy of the network on the 272 test images: 55.147
# [32,    20] loss: 0.000119
# [32,    40] loss: 0.000146
# [32,    60] loss: 0.000132
# [32,    80] loss: 0.000180
# Accuracy of the network on the 272 test images: 55.147
# [33,    20] loss: 0.000145
# [33,    40] loss: 0.000142
# [33,    60] loss: 0.000174
# [33,    80] loss: 0.000096
# Accuracy of the network on the 272 test images: 55.147
# [34,    20] loss: 0.000137
# [34,    40] loss: 0.000124
# [34,    60] loss: 0.000116
# [34,    80] loss: 0.000159
# Accuracy of the network on the 272 test images: 55.147
# [35,    20] loss: 0.000147
# [35,    40] loss: 0.000113
# [35,    60] loss: 0.000126
# [35,    80] loss: 0.000137
# Accuracy of the network on the 272 test images: 55.147
# Finished Training

# %%
# !pwd
# Out:
# /home/ccorbi/Work/Beagle/training/monkeys

# %%
#netl, neta
fig, ax = plt.subplots(1,2, figsize=(12,6))
# simple
ax[0].set_title('Loss')
ax[1].set_title('Acc')
ax[0].plot(netl)
ax[1].plot(neta)
# re nodes
ax[0].plot(bnetl)
ax[1].plot(bneta)
# extra layer
ax[0].plot(cnetl)
ax[1].plot(cneta)
fig.legend(['basic', 'bigger', 'extra_layer'], loc = 'best')
# Out:
# /home/ccorbi/anaconda3/lib/python3.5/site-packages/matplotlib/legend.py:645: UserWarning: Automatic legend placement (loc="best") not implemented for figure legend. Falling back on "upper right".
#   warnings.warn('Automatic legend placement (loc="best") not '

# %% [markdown]
# this is a clear example of how challenging id to come with better Network architectures. Bigger do not means better, and add extra convolutions must be done having in mind the nature of the data.
# There are many approaches for network optimitzation using simple random search,  or more advanced approaches using genetic and,  bayesian algorithms.
